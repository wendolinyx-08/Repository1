# %% [markdown]
# # My Second Code Notebook
#
# Notebook to test some python code

# %% [markdown]
# ## This is a Title 2
#
# ### This is Title 3
#
# #### This is Title 4
#
# ###### This is Title 6

# %% [markdown]
# This [youtube video](https://www.youtube.com/watch?v=gniNe_ZxdJU) will amaze you!

# %% [markdown]
# - Number one
# - Number two
# - Number three

# %% [markdown]
# 1. Item 1
#
#     1.1 Item 1.1
#
#     1.2 Item 1.2
#
# 2. Item 2

# %%
print("Hello world")
print("My name is Emmanuel")
# Out:
# Hello world
# My name is Emmanuel

# %% [markdown]
# ## Data types
